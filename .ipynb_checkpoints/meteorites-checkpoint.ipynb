# %% [markdown]
# ## YData Profiling: NASA Meteorites example
# Source of data: https://data.nasa.gov/Space-Science/Meteorite-Landings/gh4g-9sfh

# %% [markdown]
# The autoreload instruction reloads modules automatically before code execution, which is helpful for the update below.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Make sure that we have the latest version of pandas-profiling.

# %%
import sys

# !{sys.executable} -m pip install -U ydata-profiling[notebook]
# !pip install jupyter-contrib-nbextensions
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: ydata-profiling[notebook] in c:\users\goatf\anaconda3\lib\site-packages (0.0.dev0)
# Collecting ydata-profiling[notebook]
#   Obtaining dependency information for ydata-profiling[notebook] from https://files.pythonhosted.org/packages/79/70/1430ad64b36c3d11abd222a95c1568ee56f5a23b07224c699f2b64825bb9/ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata
#   Using cached ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.10.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (3.7.1)
# Requirement already satisfied: pydantic>=2 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.0.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (3.1.2)
# Requirement already satisfied: visions[type_image_path]<0.8.2,>=0.7.5 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.7.6)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.24.3)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.12.3)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.65.0)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.4)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.14.0)
# Requirement already satisfied: typeguard<5,>=3 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.2.1)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.9.1)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (0.57.0)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (1.0.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\goatf\anaconda3\lib\site-packages (from ydata-profiling[notebook]) (8.0.4)
# Requirement already satisfied: pillow in c:\users\goatf\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (9.4.0)
# Requirement already satisfied: PyWavelets in c:\users\goatf\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling[notebook]) (1.4.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\goatf\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (6.19.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\goatf\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (8.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\goatf\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\goatf\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\goatf\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\goatf\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling[notebook]) (2.1.1)
# Requirement already satisfied: notebook in c:\users\goatf\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.5.4)
# Requirement already satisfied: qtconsole in c:\users\goatf\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (5.4.2)
# Requirement already satisfied: jupyter-console in c:\users\goatf\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\goatf\anaconda3\lib\site-packages (from jupyter>=1.0.0->ydata-profiling[notebook]) (7.16.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\goatf\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\goatf\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\goatf\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\goatf\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\goatf\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\goatf\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\goatf\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling[notebook]) (2.8.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\goatf\anaconda3\lib\site-packages (from numba<=0.61,>=0.56.0->ydata-profiling[notebook]) (0.40.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\goatf\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling[notebook]) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\goatf\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling[notebook]) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\goatf\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling[notebook]) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\goatf\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.3.0 in c:\users\goatf\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (2.3.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\goatf\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling[notebook]) (4.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\goatf\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\goatf\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\goatf\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\goatf\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling[notebook]) (2025.1.31)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\goatf\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (0.5.3)
# Requirement already satisfied: colorama in c:\users\goatf\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling[notebook]) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\goatf\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\goatf\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling[notebook]) (3.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\goatf\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\goatf\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\goatf\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\goatf\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\goatf\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (1.5.6)
# Requirement already satisfied: psutil in c:\users\goatf\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\goatf\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\goatf\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (6.3.2)
# Requirement already satisfied: backcall in c:\users\goatf\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: decorator in c:\users\goatf\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\goatf\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\goatf\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\goatf\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\goatf\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\goatf\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: six in c:\users\goatf\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling[notebook]) (1.16.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\goatf\anaconda3\lib\site-packages (from jupyter-console->jupyter>=1.0.0->ydata-profiling[notebook]) (5.3.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\goatf\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.12.2)
# Requirement already satisfied: bleach[css]!=5.0.0 in c:\users\goatf\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\goatf\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\goatf\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\goatf\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\goatf\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.13)
# Requirement already satisfied: nbformat>=5.7 in c:\users\goatf\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (5.7.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\goatf\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (1.5.0)
# Requirement already satisfied: argon2-cffi in c:\users\goatf\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (21.3.0)
# Requirement already satisfied: ipython-genutils in c:\users\goatf\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\goatf\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\goatf\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\goatf\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\goatf\anaconda3\lib\site-packages (from notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.5)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\goatf\anaconda3\lib\site-packages (from qtconsole->jupyter>=1.0.0->ydata-profiling[notebook]) (2.2.0)
# Requirement already satisfied: webencodings in c:\users\goatf\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\goatf\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\goatf\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\goatf\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter>=1.0.0->ydata-profiling[notebook]) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\goatf\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-console->jupyter>=1.0.0->ydata-profiling[notebook]) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\goatf\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\goatf\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.2.2)
# Requirement already satisfied: fastjsonschema in c:\users\goatf\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\goatf\anaconda3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (4.17.3)
# Requirement already satisfied: wcwidth in c:\users\goatf\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\goatf\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\goatf\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\goatf\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (2.4)
# Requirement already satisfied: executing in c:\users\goatf\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\goatf\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\goatf\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.1->ydata-profiling[notebook]) (0.2.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\goatf\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter>=1.0.0->ydata-profiling[notebook]) (0.18.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\goatf\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\goatf\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\goatf\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\goatf\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\goatf\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->ydata-profiling[notebook]) (2.21)
# Using cached ydata_profiling-4.16.1-py2.py3-none-any.whl (400 kB)
# Installing collected packages: ydata-profiling
#   Attempting uninstall: ydata-profiling
#     Found existing installation: ydata-profiling 0.0.dev0
#     Uninstalling ydata-profiling-0.0.dev0:
#       Successfully uninstalled ydata-profiling-0.0.dev0
# Successfully installed ydata-profiling-4.16.1
# WARNING: bleach 4.1.0 does not provide the extra 'css'

# %% [markdown]
# You might want to restart the kernel now.

# %% [markdown]
# ### Import libraries

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import requests

import ydata_profiling
from ydata_profiling.utils.cache import cache_file
# Out:
# C:\Users\goatf\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# ### Load and prepare example dataset
# We add some fake variables for illustrating pandas-profiling capabilities

# %%
file_name = cache_file(
    "meteorites.csv",
    "https://data.nasa.gov/api/views/gh4g-9sfh/rows.csv?accessType=DOWNLOAD",
)

df = pd.read_csv(file_name)

# Note: Pandas does not support dates before 1880, so we ignore these for this analysis
df["year"] = pd.to_datetime(df["year"], errors="coerce")

# Example: Constant variable
df["source"] = "NASA"

# Example: Boolean variable
df["boolean"] = np.random.choice([True, False], df.shape[0])

# Example: Mixed with base types
df["mixed"] = np.random.choice([1, "A"], df.shape[0])

# Example: Highly correlated variables
df["reclat_city"] = df["reclat"] + np.random.normal(scale=5, size=(len(df)))

# Example: Duplicate observations
duplicates_to_add = pd.DataFrame(df.iloc[0:10])
duplicates_to_add["name"] = duplicates_to_add["name"] + " copy"

df = pd.concat([df, duplicates_to_add], ignore_index=True)

# %% [markdown]
# ### Inline report without saving object

# %%
report = df.profile_report(
    sort=None, html={"style": {"full_width": True}}, progress_bar=False
)
report

# %% [markdown]
# ### Save report to file

# %%
profile_report = df.profile_report(html={"style": {"full_width": True}})
profile_report.to_file("/tmp/example.html")

# %% [markdown]
# ### More analysis (Unicode) and Print existing ProfileReport object inline

# %%
profile_report = df.profile_report(
    explorative=True, html={"style": {"full_width": True}}
)
profile_report

# %% [markdown]
# ### Notebook Widgets

# %%
profile_report.to_widgets()
